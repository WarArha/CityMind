# %%
# Out:
#   Run mode:
#   1. Interactive (you enter values)
#   2. Demo (pre-set values, shows all features)
#
# ════════════════════════════════════════════════════════════
#   Welcome to CityMind - Challenge 1: City Layout Planner
# ════════════════════════════════════════════════════════════
#
#   Enter how many of each location type to place:
#   (Enter 0 if you don't want that type)
